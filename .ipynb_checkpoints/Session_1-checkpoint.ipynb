# %%
# start
a=10
a

# shift+enter at a time

# there is a square box 
# inside square box the number indicates, that many time we ran our cell
# Out:
# 10

# %%
b=30
b
# Out:
# 30

# %%
a+b
# what is the value of a=?
# is that value of a is defined above this cell or not?
# what is the value of b=?
# is that defined or not?
# step by step
# Out:
# 40

# %%
a=10  # 10 is value stored in a variable a
b=20  # 20 is value stored in a variable b
c=a+b # 10+20=30  stored in a variable c
c
# Out:
# 30

# %%
# if kernel is idle ==== white color dot
# if kernel is busy ===== black color dot
# so when kernel is busy, do not run any other cells
# it will not 
# in the input square box  will see * mark
# both black dot and * mark indicates kernel is busy
# Kernel is busy , you are observing * mark also
# if you want to stop it
# go to kernel
# click: Restart kernel and clear output
        # again a pop up will come
        # click on restart button

# %%
#for i in range(10000000):print(i)

# %%
a=10
a
# Out:
# 10

# %% [markdown]
# # Markdown
#
# ## if you want to write something on jupyter notebook
#
# ### Select the particular cell
#
# #### where you want write an information
#
# ##### Go to the code option and select markdown
#
# ###### Do shift+enter (means run the cell)

# %% [markdown]
# - Today im learning python
#
# - I understood about kernel busy
#
# - I understood how to run the cell
#
# - I understood how to interrupt the kernel
#
# - I understood how to restart the kernel
#
# - I understood how to markdown the cell
#
# - Code mode means, Inputs square bracket wil there

# %% [markdown]
# Sir, what is the difference between markdown and comments.
# When to use markdown or comment specifically
#
# comment means you are writing about particular code of line
# comment will works only code mode  by using single #
#
# Markdown tell about entire code notebook
# what you are goint to do

# %%
hello python  
esc+m
# Out:
#   Cell In[8], line 1
#     hello python
#           ^
# SyntaxError: invalid syntax

# %%
esc+m :  code ====> Markdown
esc+y :  markdown ==== > Code

# %% [markdown]
# <img src="data:image/jpeg;base64,..." data-deferred="1" class="rg_i Q4LuWd" jsname="Q4LuWd" width="165" height="180" alt="Python (programming language) - Wikipedia" data-iml="927.2999999998137" data-atf="true">

# %% [markdown]
# <img src="data:image/jpeg;base64,..." data-deferred="1" class="rg_i Q4LuWd" jsname="Q4LuWd" width="165" height="180" alt="Python (programming language) - Wikipedia" data-iml="927.2999999998137" data-atf="true">

# %%
CTRL+A
CTRL+C
CTRL+V
ESC+M
SHIFT+ENTER

# %% [markdown]
# <img src="https://ciracollege.com/wp-content/uploads/2020/11/How-to-Learn-Python.jpg" jsaction="VQAsE" class="sFlh5c pT0Scc iPVvYb" style="max-width: 1171px; height: 218px; margin: 0px; width: 465px;" alt="Why Python programming is the future? | CIRA Blog | CIRA College" jsname="kn3ccd" aria-hidden="false">

# %%
a=10 # we need to tell to him

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:1400/0*pU8l4-u0s1flFQiU.png" jsaction="VQAsE" class="sFlh5c pT0Scc iPVvYb" style="max-width: 1280px; height: 199px; margin: 0px; width: 353px;" alt="Functional Programming in Python: Concepts, Modules &amp; Patterns | by: Akava  | Akava" jsname="kn3ccd" data-ilt="1711984395571" aria-hidden="false">

# %%
# Laptop problem
memory is not enough
restart your laptop
delete all unwanted

# %% [markdown]
# Im implementing an addition program
# here im taking two variables
# im adding those, and

# %%
a=10 # 10 is a value stored in a
b=10 #
c=a+b
c
# Out:
# 20

# %% [markdown]
# # anoop
