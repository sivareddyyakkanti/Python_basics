# %% [markdown]
# $print$

# %% [markdown]
# **print**

# %%
number=100
print(number)
# Out:
# 100

# %%
number=100
number
# Out:
# 100

# %%
number1=100
number2=200
number1
number2

# 100
# 200
# Out:
# 200

# %%
number1=100
number2=200
print(number1)
print(number2)
# Out:
# 100
# 200

# %%
print(number1,number2)
# Out:
# 100 200

# %%
print(100)
print(200)
print(100,200,300)
# Out:
# 100
# 200
# 100 200 300

# %%
a=10
b=20
c=a+b
print(a)
print(b)
print(c)
print(a+b)
# Out:
# 10
# 20
# 30
# 30

# %%
# "the values of 10 and 20 is 30"

# %%
print("the addition of 10 and 20 is 30")
# Out:
# the addition of 10 and 20 is 30

# %%
print("the addition of 10 and 20:30")
# Out:
# the addition of 10 and 20:30

# %%
print("the addition of 10 + 20=30")
# Out:
# the addition of 10 + 20=30

# %%
# what ever we are writing in quotes, that will be print

# %%
num1=100
num2=200
num3=num1+num2
# "the addition of 100 and 200 is 300"
print("the addition of num1 and num2 is num3")
# Out:
# the addition of num1 and num2 is num3

# %%
print("the addition of",num1,"and",num2,"is",num3,".")
# single quotes 
# double quotes both will works
# Out:
# the addition of 100 and 200 is 300 .

# %%
print(100,200)
# Out:
# 100 200

# %%
# Take 3 varaibles
# name="python"
# age ="10"
# city="Hyd"
# "My name is python, Im 10 years old. And Im from hyderabad"

# %%
print("My name is python,Im 10 years old.And Im from Hyderabad")
# Out:
# My name is python,Im 10 years old.And Im from Hyderabad

# %%
name="Python"
age=10
city="Hyd"
print("My name is",name,"Im",age,"years old","and","Im from",city)
# Out:
# My name is Python Im 10 years old and Im from Hyd

# %% [markdown]
# **format**

# %%
num1=100
num2=200
num3=num1+num2
# "the addition of 100 and 200 is 300"
print("the addition of {} and {} is {}".format(num1,num2,num3))
# Out:
# the addition of 100 and 200 is 300

# %%
# Take 3 varaibles
# name="python"
# age ="10"
# city="Hyd"
# "My name is python, Im 10 years old. And Im from hyderabad"

# %%
name="srinath"
print("my name is {}".format(name))
# Out:
# my name is srinath

# %%
name="python"
age ="10"
city="Hyd"
print("My name is python, Im 10 years old. And Im from hyderabad")
print("My name is {}, Im {} years old. And Im from {}")
print("My name is {}, Im {} years old. And Im from {}".format(name,age,city))
# Out:
# My name is python, Im 10 years old. And Im from hyderabad
# My name is {}, Im {} years old. And Im from {}
# My name is python, Im 10 years old. And Im from Hyd

# %% [markdown]
# **fstring**

# %%
num1=100
num2=200
num3=num1+num2
# "the addition of 100 and 200 is 300
print("the addition of 100 and 200 is 300")
print("the addition of {} and {} is {}".format(num1,num2,num3))
print(f"the addition of {num1} and {num2} is {num3}")
# Out:
# the addition of 100 and 200 is 300
# the addition of 100 and 200 is 300
# the addition of 100 and 200 is 300

# %%
name="python"
age ="10"
city="Hyd"
print("My name is python, Im 10 years old. And Im from hyderabad")
print("My name is {}, Im {} years old. And Im from {}")
print("My name is {}, Im {} years old. And Im from {}".format(name,age,city))
print(f"My name is {name}, Im {age} years old. And Im from {city}")
# Out:
# My name is python, Im 10 years old. And Im from hyderabad
# My name is {}, Im {} years old. And Im from {}
# My name is python, Im 10 years old. And Im from Hyd
# My name is python, Im 10 years old. And Im from Hyd

# %%
number1=100
number2=200
sum1=number1+number2
sub1=number2-number1
mul=number1*number2
div=number1/number2
# The addition of num1 and num2 is sum1
# The subtraction of num1 and num2 is sub1
# The multiplication of num1 and num2 is mul
# The division of num1 and num2 is div

# %%
print("My name is {name} I'm {age} years old and I'm from {city}")
# Out:
#   Cell In[67], line 1
#     print("My name is {name} I'm {age} years old and I'm from {city})
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
number1=100
number2=200
sum1=number1+number2
sub1=number1-number2
mul1=number1*number2
div1=number1/number2
print(f"mul1 is {mul1}, sum1 is {sum1}, div1 is {div1}, sub1 is {sub1}")
# Out:
# mul1 is 20000, sum1 is 300, div1 is 0.5, sub1 is -100

# %%
num1=100
num2=200
sum1=number1+number2
sub1=number2-number1
mul1=number1*number2
div=number/number2
print("the subtraction of 200 and 100 is 100")
print("the subtraction of {} and {} is {}".format (num2,num1,sub1))
print(f"the subtraction of {num2} and {num1} is {sub1}")
# Out:
# the subtraction of 200 and 100 is 100
# the subtraction of 200 and 100 is 100
# the subtraction of 200 and 100 is 100

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\omkar'

# %% [markdown]
# - Normal statements by using ,
#
# - format method
#
# - f string method

# %%
name1="python"
name2="jupyter notebook"
# "if you want to write python program , you need to open jupyter notebook"
print("if you want to write python program , you need to open jupyter notebook")
print("if you want to write",name1,"program, you need to open",name2)
print("if you want to write {} program , you need to open {}".format(name1,name2))
print(f"if you want to write {name1} program , you need to open {name2}")
# Out:
# if you want to write python program , you need to open jupyter notebook
# if you want to write python program, you need to open jupyter notebook
# if you want to write python program , you need to open jupyter notebook
# if you want to write python program , you need to open jupyter notebook

# %%
print("hello")
print("python")

# "hello python"
# Out:
# hello
# python

# %%
# using two print statements like above
# I want to print in a single line

# %% [markdown]
# **end**

# %%
print("hello",end="&")
print("python")
# Out:
# hello&python

# %%
print(10,end=' ')
print(20,end=' ')
print(30)
# Out:
# 10 20 30

# %% [markdown]
# **sep**

# %%
print(10,20,30,sep=',')

# 10,20,30
# Out:
# 10,20,30

# %% [markdown]
# **Note**
#
#  - if you want use end operator, minimum two print statements should be there
#
#  - **end** means joining the two print statements
#
#  - you can join with any spl charcater, any name or any number
#
#  - Inside print statements we can print many values
#
#  - If you want to seperate those value use **sep operator**

# %% [markdown]
# - Normal print
#
# - Format
#
# - f string
#
# - end
#
# - sep
