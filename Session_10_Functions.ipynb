# %% [markdown]
# **Functions**

# %% [markdown]
# - function is lines of code which can be reused again
#
# - A big lines code can divide into smaller parts of code to easy to understand

# %% [markdown]
# **Functions with arguments**

# %%
num1=eval(input("Enter num1: "))
num2=eval(input("Enter num1: "))
add=num1+num2
print(add)
# Out:
# Enter num1:  100
# Enter num1:  200
# 300

# %%
def <function_name>():
    # code will start here

# same variable define rules
# are applicable for function name

# %%
def addition():
    print('addition function starts')
    n1=100
    n2=200
    add=n1+n2
    print("addition is:",add)

# %%
addition()
# Out:
# addition is: 300

# %%
def addition1():
    print('addition1 function starts')
    n1 = eval(input("Enter the number1: "))
    n2 = eval(input("Enter the number2: "))
    add = n1 + n2
    print("Addition is: ",add)

addition1()
# Out:
# addition1 function starts
# Enter the number1:  10
# Enter the number2:  20
# Addition is:  30

# %%
import random
def addition2():
    print('addition2 function starts')
    n1 =random.randint(1,10)
    n2 =random.randint(10,20)
    add = n1 + n2
    print(f"the addition of {n1} and {n2} is : {add}")

addition2()
# Out:
# addition2 function starts
# the addition of 8 and 14 is : 22

# %%
addition()
addition1()
addition2()
# Out:
# addition function starts
# addition is: 300
# addition1 function starts
# Enter the number1:  100
# Enter the number2:  200
# Addition is:  300
# addition2 function starts
# the addition of 2 and 10 is : 12

# %%
def addition3():
    try:
        print('addition3 function starts')
        n1=100
        n2=200
        add=n1+n2
        print("addition is:",add)
    except Exception as e:
        print(e)

# %%
addition3()
# Out:
# addition3 function starts
# addition is: 300

# %%
try:
    addition3()
except Exception as e:
    print(e)
# Out:
# addition3 function starts
# addition is: 300

# %%
# wap ask the user take three number
# find the average implement using function call

# wap ask the user enter the bill amount
# ask the user enter tip percentage
# and find the total bill implemente the functions

# Wap ask the user enter a random number
# find it is even or odd, implement a function

# Wap ask the user enter number
# print postive if the number >0
# print negative if the number <0
# print zero if it is zer0  Implement the function

# Implement the game program 
# num1 randomly between 1 to 10
# enter num2
# if num1 and num2 are equal then print you won
# else fail

# %%
def total_bill():
    bill=eval(input("enter the number:"))
    tip=eval(input("enter the tip in %:"))
    tip_amount=(bill*tip)/100
    total_bill=tip_amount+bill
    print("the total bill is:",total_bill)
total_bill()
# Out:
# enter the number: 100
# enter the tip in %: 10
# the total bill is: 110.0

# %%
12345
# 54321

# %%
12345%10
# Out:
# 5

# %%
12345//10
# Out:
# 1234

# %%
1234%10
# Out:
# 4

# %%
1234//10
# Out:
# 123

# %%
180

100  50  10
one 100
one 50
three 10rs

# %%
# wap ask the user take three number
# find the average implement using function call

# wap ask the user enter the bill amount
# ask the user enter tip percentage
# and find the total bill implemente the functions

# Wap ask the user enter a random number
# find it is even or odd, implement a function

# Wap ask the user enter number
# print postive if the number >0
# print negative if the number <0
# print zero if it is zer0  Implement the function

# Implement the game program 
# num1 randomly between 1 to 10
# enter num2
# if num1 and num2 are equal then print you won
# else fail

# %%
# wap ask the user take three number
# find the average implement using function call

def average():
    n1=eval(input("enter a n1:"))
    n2=eval(input("enter a n2:"))
    n3=eval(input("enter a n3:"))
    avg=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg}")

average()
# Out:
# enter a n1: 10
# enter a n2: 20
# enter a n3: 30
# the average of 10,20 and 30 is 20.0

# %%
def addition1():
    print('addition1 function starts')
    n1 = eval(input("Enter the number1: "))
    n2 = eval(input("Enter the number2: "))
    add = n1 + n2
    print("Addition is: ",add)

addition1()
# Out:
# addition1 function starts
# Enter the number1:  20
# Enter the number2:  30
# Addition is:  50

# %%
average()
addition1()
# Out:
# <function __main__.average()>

# %% [markdown]
# - inside the bracket if we write anything it is called as arguments
#
# - in average()  and addition1()  nothing has written inside the bracket
#
# - This type of functions are called as **Functions with out arguments**

# %% [markdown]
# **Functions with arguments**

# %%
def addition1():
    print('addition1 function starts')
    n1 = eval(input("Enter the number1: "))
    n2 = eval(input("Enter the number2: "))
    add = n1 + n2
    print("Addition is: ",add)

addition1()

# Total how many variables
#  n1   n2   add

# how many variables are user providing 
#  n1  n2

# so these two variables we can provide inside the bracket

# %%
def addition1(n1,n2):
    print('addition1 function starts')
    add = n1 + n2
    print("Addition is: ",add)

addition1(100,200)
# Out:
# addition1 function starts
# Addition is:  300

# %%
try:
    def addition1(n1,n2):
        try:
            print('addition1 function starts')
            add = n1 + n2
            print("Addition is: ",add)
    
        except Exception as e:
            print(e)

except Exception as e:
    print(e)

addition1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 14
#      11 except Exception as e:
#      12     print(e)
# ---> 14 addition1()
#
# TypeError: addition1() missing 2 required positional arguments: 'n1' and 'n2'

# %%
def average(n1,n2,n3):
    avg=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg}")

average(100,200,300)
# Out:
# the average of 100,200 and 300 is 200.0

# %%
def average(n1,n2):
    print("num1:",n1)  
    print("num2:",n2)
    n3 = eval(input("Enter the number3: "))
    avg=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg}")

average(100,200)
# step-1:  "num1":100
# step-2:  "num2":200
# step-3:  "enter the number3:" 300
# step-4:   avg
# step-5: print the avg
# Out:
# num1: 100
# num2: 200
# Enter the number3:  300
# the average of 100,200 and 300 is 200.0

# %%
def average(n1):
    print("num1:",n1)  
    n2 = eval(input("Enter the number2: "))
    n3 = eval(input("Enter the number3: "))
    avg=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg}")
average(100)
# Out:
# num1: 100
# Enter the number2:  200
# Enter the number3:  300
# the average of 100,200 and 300 is 200.0

# %%
a+b+c/3   wrong   calculator   mobile
(a+b+c)/3

# %%
round(16.66666,2)
# Out:
# 16.67

# %%
def average(n1):
    print("num1:",n1)  
    n2 = eval(input("Enter the number2: "))
    n3 = eval(input("Enter the number3: "))
    avg=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg}")
average(eval(input("Enter the number1: ")))
# Out:
# Enter the number1:  100
# num1: 100
# Enter the number2:  200
# Enter the number3:  300
# the average of 100,200 and 300 is 200.0

# %%
# name error: n1 not defined
def average():
    avg=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg}")
average()
###########################################################
# argment error:  
#average1() missing 1 required positional argument: 'n1'
def average1(n1):
    avg=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg}")
average1()

############################################################
# name error : n2 not defined
def average2(n1):
    avg=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg}")
average2(100)

############################################################
# one postitional argument is missing
def average3(n1,n2,n3):
    avg=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg}")
average3(100,200)

############################################################
# expected 3 argumments, we given four
def average4(n1,n2,n3):
    avg=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg}")
average4(100,200,300,400)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 10
#       8     avg=round((n1+n2+n3)/3,2)
#       9     print(f"the average of {n1},{n2} and {n3} is {avg}")
# ---> 10 average1()
#
# TypeError: average1() missing 1 required positional argument: 'n1'

# %%
# wap ask the user enter the bill amount
# ask the user enter tip percentage
# and find the total bill implemente the functions
# create function with arguments in all the ways

# %% [markdown]
# **Note**
#
# - Function name , variable names should be different

# %%
def bill():
    bill_amount=eval(input("enter the bill amount:"))
    tip_per=eval(input("enter the tip_per:"))
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill()
# Out:
# enter the bill amount: 1000
# enter the tip_per: 10
# total_bill is: 1100.0

# %%
def bill(bill_amount,tip_per):
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(1000,10)
# Out:
# total_bill is: 1100.0

# %%
def bill(bill_amount):
    tip_per=eval(input("enter the tip_per:"))
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(1000)
# Out:
# enter the tip_per: 10
# total_bill is: 1100.0

# %%
def bill(tip_per):
    bill_amount=eval(input("enter the bill_amount:"))
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(10)
# Out:
# enter the bill_amount: 1000
# total_bill is: 1100.0

# %%
def bill(bill_amount):
    tip_per=eval(input("enter the tip_per:"))
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(eval(input("enter the bill_amount:")))
# Out:
# enter the bill_amount: 1000
# enter the tip_per: 10
# total_bill is: 1100.0

# %%
def bill(bill_amount,tip_per):
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(eval(input("enter the bill_amount:")),
     eval(input("enter the tip_per:")))
# Out:
# enter the bill_amount: 100
# enter the tip_per: 10
# total_bill is: 110.0

# %%
def bill():
    bill_amount=eval(input("enter the bill amount:"))
    tip_per=eval(input("enter the tip_per:"))
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill()

def bill(bill_amount,tip_per):
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(1000,10)

def bill(tip_per):
    bill_amount=eval(input("enter the bill_amount:"))
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(10)

def bill(bill_amount):
    tip_per=eval(input("enter the tip_per:"))
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(eval(input("enter the bill_amount:")))


def bill(bill_amount,tip_per):
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(eval(input("enter the bill_amount:")),
     eval(input("enter the tip_per:")))

# %% [markdown]
# **Default parameters**

# %%
def bill(bill_amount,tip_per=20):
    print("bill:",bill_amount)
    print("tip_per:",tip_per)
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(1000)
# Out:
# bill: 1000
# tip_per: 20
# total_bill is: 1200.0

# %%
# case-1:  Make constnat or default all the parameters
def bill(bill_amount=1000,tip_per=20):
    print("bill:",bill_amount)
    print("tip_per:",tip_per)
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill()
# Out:
# bill: 1000
# tip_per: 20
# total_bill is: 1200.0

# %%
# Case-2: make sure that default argumnets should be at last
# keep tip_per as first arguments
def bill(bill_amount=1000,tip_per):
    print("bill:",bill_amount)
    print("tip_per:",tip_per)
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(20)
# Out:
#   Cell In[38], line 1
#     def bill(bill_amount=1000,tip_per):
#                               ^
# SyntaxError: non-default argument follows default argument

# %%
def bill(tip_per,bill_amount=1000):
    print("bill:",bill_amount)
    print("tip_per:",tip_per)
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(20)
# Out:
# bill: 1000
# tip_per: 20
# total_bill is: 1200.0

# %%
avergae(n1,n2,n3)  # w
average(n1,n2,n3=100) # w
average(n1,n2=100,n3) # F  default parameter always at last
average(n1,n3,n2=100)
average(n1=100,n2,n3) # F
average(n1,n2=100,n3=100) # w
average(n1,n3=100,n2=100)
average(n1=100,n2,n3=100) # F
average(n1=100,n2=100,n3) # F
average(n1=100,n2=100,n3=100) #W

# %%
# Case-3: Values can be overwrite
def bill(bill_amount,tip_per=10):
    print("bill:",bill_amount)
    print("tip_per:",tip_per)
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(2000,20)
# Out:
# bill: 2000
# tip_per: 20
# total_bill is: 2400.0

# %%
def bill(bill_amount=1000,tip_per=10):
    print("bill:",bill_amount)
    print("tip_per:",tip_per)
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(2000,20)
# Out:
# bill: 2000
# tip_per: 20
# total_bill is: 2400.0

# %%
# Case-4:
# define the function
# call the function
# run the function
# latest value will be taken
def bill(bill_amount=1000,tip_per=10):
    bill_amount=3000
    print("bill:",bill_amount)
    print("tip_per:",tip_per)
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(2000,20)
# Out:
# bill: 3000
# tip_per: 20
# total_bill is: 3600.0

# %%
# case-5:
# if you provide the value by using exact names
# position does not matter
def bill(bill_amount=1000,tip_per=10):
    bill_amount=3000
    print("bill:",bill_amount)
    print("tip_per:",tip_per)
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill(tip_per=30,bill_amount=500)
# Out:
# bill: 3000
# tip_per: 500
# total_bill is: 18000.0

# %%
bill_amount=10000
def bill(tip_per=10):
    print("bill:",bill_amount)
    print("tip_per:",tip_per)
    tip_amount=bill_amount*tip_per/100
    total_bill=bill_amount+tip_amount
    print("total_bill is:",total_bill)

bill()
# Out:
# bill: 10000
# tip_per: 10
# total_bill is: 11000.0

# %%
text book  
hacker rank
great learning certification
140 question python

syntax error
name error
indentation error
attribute error
type error
argument error

# %% [markdown]
# - Functions with out arguments
#
# - Functions with arguments
#
# - Functions default arguments

# %% [markdown]
# **local variable and Global variable**
#
# - local variables means the variable provide inside function
#
# - Global variable means the variable provide outside function

# %%
def addition1():
    print('addition1 function starts')
    n1 = eval(input("Enter the number1: "))
    n2 = eval(input("Enter the number2: "))
    add = n1 + n2
    print("Addition is: ",add)

addition1()
# Out:
# addition1 function starts
# Enter the number1:  100
# Enter the number2:  200
# Addition is:  300

# %%
n1 = eval(input("Enter the number1: "))
n2 = eval(input("Enter the number2: "))

def addition2():
    print('addition2 function starts')
    add = n1 + n2
    print("Addition is: ",add)

def multiplication2():
    print('multiplication function starts')
    mul = n1*n2
    print("multiplication is: ",mul)

addition2()
multiplication2()
# Out:
# Enter the number1:  100
# Enter the number2:  200
# addition2 function starts
# Addition is:  300
# multiplication function starts
# multiplication is:  20000

# %%
# Case-1
n1 =500
n2 =200

def addition3():
    n1=1000
    n2=2000
    print('addition2 function starts')
    add = n1 + n2
    print("Addition is: ",add)

addition3()
# Out:
# addition2 function starts
# Addition is:  3000

# %%
# Case-2:
n1 =500
n2 =200

def addition4():
    n1=1000
    n2=2000
    print('addition2 function starts')
    add = n1 + n2
    print("Addition is: ",add)

n1 =5000
n2 =2000
addition4()

# 500 ---- > 5000 --- > 1000
# 200 ---- > 2000 ---- > 2000
# Out:
# addition2 function starts
# Addition is:  3000

# %%
# Case-3:
n1 =500
n2 =200

def addition5(n1=10,n2=20):
    print('addition2 function starts')
    add = n1 + n2
    print("Addition is: ",add)

n1 =5000
n2 =2000
addition5()

# define the function
# call the function
# run the function
# n1=500 === > 5000 === > 10 ==== > 1000
# Out:
# addition2 function starts
# Addition is:  30

# %%
# Case-4:
n1 =500
n2 =200

def addition5(n1=10,n2=20):
    print('addition2 function starts')
    add = n1 + n2
    print("Addition is: ",add)

n1 =5000
n2 =2000
addition5(200,300)
# Out:
# addition2 function starts
# Addition is:  500

# %%
# Case-5:
n1 =500
n2 =200

def addition6():
    print('addition2 function starts')
    add = n1 + n2
    print("Addition is: ",add)

n1 =5000
n2 =2000
addition6()
# Out:
# addition2 function starts
# Addition is:  7000

# %%
n1 = 200
n2 = 500
add=0  # global varaible
def addition8():
    global add2
    print('addition2 function starts')
    add2= n1 + n2  # local varaible: 700
    print("Addition is: ",add)

addition8()

# The value inside the function we cant take outside
# with out return

# How can you print the updated value out side the function with out using return
# Out:
# addition2 function starts
# Addition is:  0

# %%
print(add2)
# Out:
# 700

# %%
n1 = 200
n2 = 500
add=0  # global varaible
def addition9():
    global n1,n2,add2
    print('addition2 function starts')
    n1=5000
    n2=2000
    add2= n1 + n2  # local varaible: 700
    print("Addition is: ",add2)

addition9()
# Out:
# addition2 function starts
# Addition is:  7000

# %%
add2,n1,n2    # 2000
# Out:
# (7000, 5000, 2000)

# %%
n1=500
n2=200
add=0
def addition(n1=600,n2=700):
    global n1,n2,add 
    print("addition function starts: ")
    n1=6000
    n2=7000

    add =n1+n2
    print(add)

addition(3000,4000)
# Out:
#   Cell In[38], line 5
#     global n1,n2,add
#     ^
# SyntaxError: name 'n1' is parameter and global

# %% [markdown]
# **Note**
#
# **Global variable can not be arguments at a time**

# %%
name="kalki"
name
# Out:
# 'kalki'

# %% [markdown]
# **Return**

# %%
def average(n1,n2,n3):
    avg1=round((n1+n2+n3)/3,2)
    print(f"the average of {n1},{n2} and {n3} is {avg1}")
    return(avg1)

avg1=average(100,200,300)   # avg1= (100+200+300)/3=200
# Out:
# the average of 100,200 and 300 is 200.0

# %%
avg1
# Out:
# 200.0

# %%
def addition():
    n11=6000
    n21=7000
    add11 =n11+n21
    return(add11,n11,n21)

val=addition()

# %%
val
# Out:
# (13000, 6000, 7000)

# %%
number=1,2,3
number
# Out:
# (1, 2, 3)

# %%
def addition():
    a11=5000
    b12=2000
    c13=a11+b12  # local variable and global variable
    return(c13,a11,b12)

a11,b12,c3=addition()

# %%
def add(n1,n2):
    return(n1+n2)

add1=add(10,20)
print(add1)
# Out:
# 30

# %% [markdown]
# **Function in functions**

# %%
def greet1():
    print("good eve")

def greet2():
    print("good night")

greet1()
greet2()
# Out:
# good eve
# good night

# %%
def greet1():
    print("====greet1 function starts===")
    print("good eve")

def greet2():
    print("====greet2 function starts===")
    greet1()
    print("good night")

greet2()
# "====greet2 function starts==="
# "====greet1 function starts==="
# "good eve"
#  "good night"
# Out:
# ====greet2 function starts===
# ====greet1 function starts===
# good eve
# good night

# %%
def greet1():
    print("====greet1 function starts===")
    greet2()
    print("good eve")

def greet2():
    print("====greet2 function starts===")
    greet1()
    print("good night")

greet2()
# Out:
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ====greet1 function starts===
# ====greet2 function starts===
# ...

# %%
# First create 4 functions 
# add
# mul
# sub
# div  with direct return statements
# with out argumnents

# Create one more function called calculator
# if you want to enter 1: add 
#                enter 2: mul
#                enter 3: sub
#               enter 4: div
# n1=eval ()
# n2=eval()
# option=eval()
# if option==1: add()
# elif option==2: mul()
# elif option==3: sub()
# elif option==4: div()

# calculator()
