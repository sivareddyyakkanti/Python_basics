# %% [markdown]
# # Variables

# %% [markdown]
# - Variable has values but that can change every time

# %%
number=100
# 100 is a value stored in a variable number
number
# Out:
# 100

# %%
number=200
# 200 is a value stored in a variable number
number
# Out:
# 200

# %%
number  # it will take latest
# Out:
# 100

# %%
number2=10.5
number2
# Out:
# 10.5

# %%
name="python"
name

# python is an english word stored in a variable name
# Out:
# 'python'

# %%
city="Hyderabad"
city

# Hyderbad is a word stored in a variable city
# Out:
# 'Hyderabad'

# %% [markdown]
# **Note**
#
# - Variable is in black color
#
# - English or text in Red color

# %% [markdown]
# ## Rules for Variables

# %% [markdown]
# - Variables are case sensitive

# %%
number=500
NUMBER=600

# %%
number
# Out:
# 500

# %%
NUMBER
# Out:
# 600

# %% [markdown]
# - Variables does not start with numbers
#
# - variable does not have numbers as prefix

# %%
123number=700
123number
# Out:
#   Cell In[12], line 1
#     123number=700
#       ^
# SyntaxError: invalid decimal literal

# %%
number=100
NUMBER=200
123number=500
# Out:
#   Cell In[13], line 3
#     123number=500
#       ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# - Variables can have numbers as suffix
#
# - variables can have numbers at the end

# %%
number123=900
number123
# Out:
# 900

# %% [markdown]
# esc+m   code ==== > markdown
#
# esc+y   markdown ==== > code

# %% [markdown]
# - Variables can have uppercase and lowercase number

# %%
NUMBERnumber=800
numberNUMBER=900
NUMBERnumber,numberNUMBER
# Out:
# (800, 900)

# %% [markdown]
# - Variables does not have a spl charcters excepect underscore

# %%
number&value=100  # Fail
number$value =200 # Fail
number value=300  # Fail
# Out:
#   Cell In[17], line 1
#     number&value=100  # Fail
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
number_value=400
number_value
# Out:
# 400

# %%
_=900   # spl case
_
# Out:
# 900

# %% [markdown]
# - Keywords should not use as variables

# %%
if 
else
elif
for
while
and
or
in

# %%
if=900
if
# Out:
#   Cell In[21], line 1
#     if=900
#       ^
# SyntaxError: invalid syntax

# %%
number-value=900
number-value
# Out:
#   Cell In[22], line 1
#     number-value=900
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# - Variables are case sensitive
#
# - Variables does not start with numbers
#
# - variable does not have numbers as prefix
#
# - Variables can have numbers as suffix
#
# - variables can have numbers at the end
#
# - Variables can have uppercase and lowercase number
#
# - Variables does not have a spl charcters excepect underscore
#
# - Keywords should not use as variables

# %%
import os

# %%
os.getcwd()   # current working directory
# Out:
# 'C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Naresh IT\\Data science\\Batches\\Batch-7_Mar\\Python_sessions'
